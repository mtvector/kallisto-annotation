# %%
import os
import sys
from collections import defaultdict
import gzip
import pandas as pd
import re
import csv

GTF_HEADER  = ['seqname', 'source', 'feature', 'start', 'end', 'score',
               'strand', 'frame']
R_SEMICOLON = re.compile(r'\s*;\s*')
R_COMMA     = re.compile(r'\s*,\s*')
R_KEYVALUE  = re.compile(r'(\s+|\s*=\s*)')


def dataframe(filename):
    """Open an optionally gzipped GTF file and return a pandas.DataFrame.
    """
    # Each column is a list stored as a value in this dict.
    result = defaultdict(list)

    for i, line in enumerate(lines(filename)):
        for key in line.keys():
            # This key has not been seen yet, so set it to None for all
            # previous lines.
            if key not in result:
                result[key] = [None] * i

        # Ensure this row has some value for each column.
        for key in result.keys():
            result[key].append(line.get(key, None))

    return pd.DataFrame(result)


def lines(filename):
    """Open an optionally gzipped GTF file and generate a dict for each line.
    """
    fn_open = gzip.open if filename.endswith('.gz') else open

    with fn_open(filename) as fh:
        for line in fh:
            if line.startswith('#'):
                continue
            else:
                yield parse(line)


def parse(line):
    """Parse a single GTF line and return a dict.
    """
    result = {}

    fields = line.rstrip().split('\t')

    for i, col in enumerate(GTF_HEADER):
        result[col] = _get_value(fields[i])

    # INFO field consists of "key1=value;key2=value;...".
    infos = [x for x in re.split(R_SEMICOLON, fields[8]) if x.strip()]

    for i, info in enumerate(infos, 1):
        # It should be key="value".
        try:
            key, _, value = re.split(R_KEYVALUE, info, 1)
        # But sometimes it is just "value".
        except ValueError:
            key = 'INFO{}'.format(i)
            value = info
        # Ignore the field if there is no value.
        if value:
            result[key] = _get_value(value)

    return result


def _get_value(value):
    if not value:
        return None

    # Strip double and single quotes.
    value = value.strip('"\'')

    # Return a list if the value has a comma.
    if ',' in value:
        value = re.split(R_COMMA, value)
    # These values are equivalent to None.
    elif value in ['', '.', 'NA']:
        return None

    return value
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
common_name='Name'
common_id='gene_id'
transcript_or_gene='transcript'
gtf = dataframe('/wynton/group/ye/mtschmitz/refdata2/rhemac10/CAT_chang/Rhesus.gtf')
gtf = gtf.fillna('')
print(gtf)
print(list(gtf.columns))

# %%
tgtf=gtf.loc[gtf['feature']=='transcript',:]
tgtf.loc[:,['transcript_id',common_id]]
tgtf.drop_duplicates(subset = ['transcript_id'], keep = 'first', inplace = True) 

ggtf=gtf.loc[gtf['feature']=='transcript',:]
ggtf.drop_duplicates(subset = [common_id], keep = 'first', inplace = True) 
gdict=dict(zip(ggtf[common_id],ggtf[common_name]))
#ggtf.loc[:,[common_id,common_name]]
tgtf[common_name]=list(tgtf[common_id].replace(gdict))
# Out:
# /wynton/home/ye/mschmitz1/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /wynton/home/ye/mschmitz1/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/tmp/ipykernel_16152/1360637079.py in <module>
#       7 gdict=dict(zip(ggtf[common_id],ggtf[common_name]))
#       8 #ggtf.loc[:,[common_id,common_name]]
# ----> 9 tgtf[common_name]=list(tgtf[common_id].replace(gdict))
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4567             limit=limit,
#    4568             regex=regex,
# -> 4569             method=method,
#    4570         )
#    4571
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6499
#    6500             return self.replace(
# -> 6501                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6502             )
#    6503         else:
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4567             limit=limit,
#    4568             regex=regex,
# -> 4569             method=method,
#    4570         )
#    4571
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6545                         dest_list=value,
#    6546                         inplace=inplace,
# -> 6547                         regex=regex,
#    6548                     )
#    6549
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in comp(s, mask, regex)
#     634
#     635             s = com.maybe_box_datetimelike(s)
# --> 636             return _compare_or_regex_search(values, s, regex, mask)
#     637
#     638         # Calculate the mask once, prior to the call of comp
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in _compare_or_regex_search(a, b, regex, mask)
#    1986         mask = np.reshape(~(isna(a)), a.shape)
#    1987     if isinstance(a, np.ndarray):
# -> 1988         a = a[mask]
#    1989
#    1990     if is_datetimelike_v_numeric(a, b) or is_numeric_v_string_like(a, b):
#
# KeyboardInterrupt:

# %%
tgtf[common_name]=list(tgtf[common_id].replace(gdict))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/tmp/ipykernel_16152/748616568.py in <module>
# ----> 1 tgtf[common_name]=list(tgtf[common_id].replace(gdict))
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4568             regex=regex,
# -> 4569             method=method,
#    4570         )
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6500             return self.replace(
# -> 6501                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6502             )
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4568             regex=regex,
# -> 4569             method=method,
#    4570         )
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6546                         inplace=inplace,
# -> 6547                         regex=regex,
#    6548                     )
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in comp(s, mask, regex)
#     635             s = com.maybe_box_datetimelike(s)
# --> 636             return _compare_or_regex_search(values, s, regex, mask)
#     637
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in _compare_or_regex_search(a, b, regex, mask)
#    1994
# -> 1995     result = op(a)
#    1996
#
# ~/utils/miniconda3/envs/kallisto2/lib/python3.7/site-packages/pandas/core/internals/managers.py in <lambda>(x)
#    1975     if not regex:
# -> 1976         op = lambda x: operator.eq(x, b)
#    1977     else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
gtf['feature'].unique()
# Out:
# array(['transcript', 'exon', 'CDS'], dtype=object)

# %%
ggtf
# Out:
#         seqname source     feature     start       end score strand frame  \
# 0          chr1    CAT  transcript      7416     13554  9450      -
# 17         chr1    CAT  transcript     14267     14369  3520      +
# 19         chr1    CAT  transcript     65269     71509  8050      -
# 24         chr1    CAT  transcript     71366     80765  9000      +
# 321        chr1    CAT  transcript     81255     91705  9530      -
# ...         ...    ...         ...       ...       ...   ...    ...   ...
# 3322866    chrY    CAT  transcript  10104323  10117294            +
# 3322949    chrY    CAT  transcript  10529111  10529943            -
# 3322954    chrY    CAT  transcript  10630192  10630413            +
# 3322957    chrY    CAT  transcript  10630593  10690186            +
# 3323148    chrY    CAT  transcript  10630593  10696542            +
#
#            transcript_id          gene_id  ...             Name rna_support  \
# 0        Rhesus_T0000001  Rhesus_G0000001  ...            PGBD2        True
# 17       Rhesus_T0000005  Rhesus_G0000002  ...       RNU6-1205P        True
# 19       Rhesus_T0000006  Rhesus_G0000003  ...       AL672291.1        True
# 24       Rhesus_T0000007  Rhesus_G0000004  ...           ZNF692        True
# 321      Rhesus_T0000038  Rhesus_G0000005  ...           ZNF672        True
# ...                  ...              ...  ...              ...         ...
# 3322866  Rhesus_T0262195  Rhesus_G0066375  ...  Rhesus_G0066375        True
# 3322949  Rhesus_T0262198  Rhesus_G0066376  ...  Rhesus_G0066376        True
# 3322954  Rhesus_T0262199  Rhesus_G0066377  ...  Rhesus_G0066377        True
# 3322957  Rhesus_T0262201  Rhesus_G0066379  ...  Rhesus_G0066379        True
# 3323148  Rhesus_T0262200  Rhesus_G0066378  ...  Rhesus_G0066378        True
#
#         reference_support novel_5p_cap novel_poly_a  \
# 0                    True
# 17                   True
# 19                   True
# 24                   True
# 321                  True
# ...                   ...          ...          ...
# 3322866              True         True         True
# 3322949              True         True         True
# 3322954              True         True         True
# 3322957              True         True         True
# 3323148              True         True         True
#
#         alternative_source_transcripts collapsed_gene_ids  \
# 0
# 17
# 19
# 24
# 321
# ...                                ...                ...
# 3322866
# 3322949
# 3322954
# 3322957
# 3323148
#
#         collapsed_gene_names ont possible_split_gene_locations
# 0
# 17
# 19
# 24
# 321
# ...                      ...  ..                           ...
# 3322866
# 3322949
# 3322954
# 3322957
# 3323148
#
# [66379 rows x 52 columns]

# %%
tgtf
# Out:
#         seqname source     feature     start       end score strand frame  \
# 0          chr1    CAT  transcript      7416     13554  9450      -
# 4          chr1    CAT  transcript      8223     13554  9540      -
# 9          chr1    CAT  transcript      9002     13507            -
# 14         chr1    CAT  transcript      9964     13554  6640      -
# 17         chr1    CAT  transcript     14267     14369  3520      +
# ...         ...    ...         ...       ...       ...   ...    ...   ...
# 3322954    chrY    CAT  transcript  10630192  10630413            +
# 3322957    chrY    CAT  transcript  10630593  10690186            +
# 3323022    chrY    CAT  transcript  10630593  10690186            +
# 3323091    chrY    CAT  transcript  10630593  10692903            +
# 3323148    chrY    CAT  transcript  10630593  10696542            +
#
#            transcript_id          gene_id  ...             Name rna_support  \
# 0        Rhesus_T0000001  Rhesus_G0000001  ...            PGBD2        True
# 4        Rhesus_T0000002  Rhesus_G0000001  ...            PGBD2        True
# 9        Rhesus_T0000003  Rhesus_G0000001  ...            PGBD2        True
# 14       Rhesus_T0000004  Rhesus_G0000001  ...            PGBD2        True
# 17       Rhesus_T0000005  Rhesus_G0000002  ...       RNU6-1205P        True
# ...                  ...              ...  ...              ...         ...
# 3322954  Rhesus_T0262199  Rhesus_G0066377  ...  Rhesus_G0066377        True
# 3322957  Rhesus_T0262201  Rhesus_G0066379  ...  Rhesus_G0066379        True
# 3323022  Rhesus_T0262202  Rhesus_G0066379  ...  Rhesus_G0066379        True
# 3323091  Rhesus_T0262203  Rhesus_G0066379  ...  Rhesus_G0066379        True
# 3323148  Rhesus_T0262200  Rhesus_G0066378  ...  Rhesus_G0066378        True
#
#         reference_support novel_5p_cap novel_poly_a  \
# 0                    True
# 4                    True
# 9                    True         True         True
# 14                   True
# 17                   True
# ...                   ...          ...          ...
# 3322954              True         True         True
# 3322957              True         True         True
# 3323022              True         True         True
# 3323091              True         True         True
# 3323148              True         True         True
#
#         alternative_source_transcripts collapsed_gene_ids  \
# 0
# 4
# 9                             14339.t1
# 14
# 17
# ...                                ...                ...
# 3322954
# 3322957
# 3323022
# 3323091
# 3323148
#
#         collapsed_gene_names ont possible_split_gene_locations
# 0
# 4
# 9
# 14
# 17
# ...                      ...  ..                           ...
# 3322954
# 3322957
# 3323022
# 3323091
# 3323148
#
# [262203 rows x 52 columns]
